# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('churn_clean207.csv')

# %%
from scipy.stats import chi2_contingency
data = [[3753, 3425, 172], [1272, 1319, 59]]
stat, p, dof, expected = chi2_contingency(data)
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
	print('Dependent (reject H0)')
else:
	print('Independent (H0 holds true)')
# Out:
# p value is 0.019447581193944605
# Dependent (reject H0)

# %%
df=pd.read_csv('churn_clean207.csv', usecols = ['Tenure','Age'])
df.describe()
# Out:
#                 Age        Tenure
# count  10000.000000  10000.000000
# mean      53.078400     34.526188
# std       20.698882     26.443063
# min       18.000000      1.000259
# 25%       35.000000      7.917694
# 50%       53.000000     35.430507
# 75%       71.000000     61.479795
# max       89.000000     71.999280

# %%
df=pd.read_csv('churn_clean207.csv')
for col in ['Gender','Churn']:
    print(df[col].value_counts())
# Out:
# Female       5025
# Male         4744
# Nonbinary     231
# Name: Gender, dtype: int64
# No     7350
# Yes    2650
# Name: Churn, dtype: int64

# %%
df=pd.read_csv('Churn_clean207.csv')
df.groupby('Churn').size().plot.bar(rot=0)
plt.ylabel('Count')
plt.title('Distribution of Churn in Churn Dataset')
plt.show()

# %%
 
df.groupby('Gender').size().plot.bar(rot=0)
plt.ylabel('Gender')
plt.title('Distribution of Gender in Churn Dataset')
plt.show()

# %%
ax=(df['Tenure']).plot.box()
ax.set_ylabel('Tenure Distribution')
# Out:
# Text(0, 0.5, 'Tenure Distribution')

# %%
ax=(df['Age']).plot.box()
ax.set_ylabel('Age Distributions')
# Out:
# Text(0, 0.5, 'Age Distributions')

# %%
df=pd.read_csv('Churn_clean207.csv')
df = pd.crosstab(df['Churn'],
     df['Gender'],
     margins = False)
print(df)
# Out:
# Gender  Female  Male  Nonbinary
# Churn
# No        3753  3425        172
# Yes       1272  1319         59

# %%
df=pd.read_csv('Churn_clean207.csv')
df = pd.crosstab(df['Churn'],
     df['Gender'],
     normalize='index')
print(df)
# Out:
# Gender    Female      Male  Nonbinary
# Churn
# No      0.510612  0.465986   0.023401
# Yes     0.480000  0.497736   0.022264

# %%
df=pd.read_csv('Churn_clean207.csv')
tbl = pd.pivot_table(df.groupby(['Churn','Gender']).size().reset_index(),
values=0,
index='Churn',
columns=['Gender'],
aggfunc=np.sum)
tbl.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='Churn'>

# %%
 df=pd.read_csv('Churn_clean207.csv')
df.corr()
# Out:
#                       CaseOrder           Zip       Lat       Lng  Population  \
# CaseOrder              1.000000  3.007020e-03 -0.014680 -0.001363   -0.007494
# Zip                    0.003007  1.000000e+00 -0.042580 -0.901786    0.045138
# Lat                   -0.014680 -4.257985e-02  1.000000 -0.100639   -0.220598
# Lng                   -0.001363 -9.017856e-01 -0.100639  1.000000   -0.048294
# Population            -0.007494  4.513808e-02 -0.220598 -0.048294    1.000000
# Children              -0.006148 -1.720505e-02 -0.000452  0.013634   -0.005877
# Age                    0.016038 -8.135285e-03 -0.002943  0.012117    0.010538
# Income                 0.000192  2.946523e-03  0.006563 -0.002997   -0.008639
# Outage_sec_perweek    -0.001358 -1.152040e-02  0.004827  0.005646    0.005483
# Email                 -0.011274 -7.860018e-03 -0.030042  0.007872    0.017962
# Contacts               0.004361 -4.719513e-03 -0.002213  0.008118    0.004019
# ...

# %%
df=pd.read_csv('Churn_clean207.csv')
df.corr().loc['Age','Tenure']
# Out:
# 0.01697927310582298

# %%
ax=df.plot.hexbin(x='Age',y='Tenure',gridsize=30,sharex=False,figsize=(5,4))
